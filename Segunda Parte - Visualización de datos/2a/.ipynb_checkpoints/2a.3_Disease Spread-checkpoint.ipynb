# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df_labels = pd.read_csv('datasets/Dengue/dengue_labels_train.csv')
df_features = pd.read_csv('datasets/Dengue/dengue_features_train.csv')

# %%
df_labels
# Out:
#      city  year  weekofyear  total_cases
# 0      sj  1990          18            4
# 1      sj  1990          19            5
# 2      sj  1990          20            4
# 3      sj  1990          21            3
# 4      sj  1990          22            6
# ...   ...   ...         ...          ...
# 1451   iq  2010          21            5
# 1452   iq  2010          22            8
# 1453   iq  2010          23            1
# 1454   iq  2010          24            1
# 1455   iq  2010          25            4
#
# [1456 rows x 4 columns]

# %%
df_features.tail()
# Out:
#      city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 1451   iq  2010          21      2010-05-28  0.342750  0.318900  0.256343
# 1452   iq  2010          22      2010-06-04  0.160157  0.160371  0.136043
# 1453   iq  2010          23      2010-06-11  0.247057  0.146057  0.250357
# 1454   iq  2010          24      2010-06-18  0.333914  0.245771  0.278886
# 1455   iq  2010          25      2010-06-25  0.298186  0.232971  0.274214
#
#        ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# 1451  0.292514                 55.30             299.334286  ...
# 1452  0.225657                 86.47             298.330000  ...
# 1453  0.233714                 58.94             296.598571  ...
# 1454  0.325486                 59.67             296.345714  ...
# 1455  0.315757                 63.22             298.097143  ...
#
#       reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
# ...

# %%
def week_to_season(weekofyear):
    seasons = []
    for i in weekofyear:
        if i >= 48 or i < 9:
            seasons.append('SUM')
        elif 9 <= i and i < 22:
            seasons.append('AUT')
        elif 22 <= i and i < 35:
            seasons.append('WIN')
        elif 35 <= i and i < 48:
            seasons.append('SPR')
    return pd.Series(seasons)

# %%
df_labels['season'] = week_to_season(df_labels['weekofyear'])
df_labels
# Out:
#      city  year  weekofyear  total_cases season
# 0      sj  1990          18            4    AUT
# 1      sj  1990          19            5    AUT
# 2      sj  1990          20            4    AUT
# 3      sj  1990          21            3    AUT
# 4      sj  1990          22            6    WIN
# ...   ...   ...         ...          ...    ...
# 1451   iq  2010          21            5    AUT
# 1452   iq  2010          22            8    WIN
# 1453   iq  2010          23            1    WIN
# 1454   iq  2010          24            1    WIN
# 1455   iq  2010          25            4    WIN
#
# [1456 rows x 5 columns]

# %%
df_features['season'] = week_to_season(df_features['weekofyear'])
df_features['season']
# Out:
# 0       AUT
# 1       AUT
# 2       AUT
# 3       AUT
# 4       WIN
#        ...
# 1451    AUT
# 1452    WIN
# 1453    WIN
# 1454    WIN
# 1455    WIN
# Name: season, Length: 1456, dtype: object

# %%
sns.set_theme(font_scale=1.5)
sns.set_style("whitegrid")
f,axs=plt.subplots(nrows=2,figsize=(15,15))
g1=sns.barplot(x='season',y='total_cases',hue='city',data=df_labels,ax=axs[0],
              palette='Reds')
g1.set_ylabel('Total Cases')
g1.set_xlabel('Seasons')
g2=sns.violinplot(x='season',y='station_avg_temp_c',hue='city',data=df_features,
                  split=True,ax=axs[1],
                  palette='flare')
g2.set_ylabel('Average Temperature')
g2.set_xlabel('Seasons')
g1.set_title('Season Comparison Between Total Cases and Average Temperature ')
# Out:
# Text(0.5, 1.0, 'Season Comparison Between Total Cases and Average Temperature ')

# %%
plt.subplots(figsize=(20,10))
g = sns.histplot(df_features.reanalysis_relative_humidity_percent,stat='frequency',binrange=(65,100),color='b',element='step',kde=True)
g.set_xlabel('Mean Relative Humidity')
g.set_title('Frequency of Mean Relative Humidity',fontdict={'fontsize':25})
# Out:
# Text(0.5, 1.0, 'Frequency of Mean Relative Humidity')
