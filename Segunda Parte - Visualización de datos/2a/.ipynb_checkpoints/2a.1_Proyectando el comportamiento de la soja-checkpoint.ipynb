# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
soja_df = pd.read_csv('datasets/Comportamiento de la soja/datasetRofex4 - datasetRofex2.csv')

# %%
soja_df
# Out:
#         Id                     Fecha  Open  High  Low  Last  Cierre  Aj.Dif.  \
# 0        1  05/01/2004 12:00:00 a.m.   0.0   0.0  0.0   0.0   221.0     13.0
# 1        2  06/01/2004 12:00:00 a.m.   0.0   0.0  0.0   0.0   221.0      0.0
# 2        3  07/01/2004 12:00:00 a.m.   0.0   0.0  0.0   0.0   219.0     -2.0
# 3        4  08/01/2004 12:00:00 a.m.   0.0   0.0  0.0   0.0   220.0      1.0
# 4        5  09/01/2004 12:00:00 a.m.   0.0   0.0  0.0   0.0   220.0      0.0
# ...    ...                       ...   ...   ...  ...   ...     ...      ...
# 3870  3871  23/09/2019 12:00:00 a.m.   0.0   0.0  0.0   0.0   238.0      0.0
# 3871  3872  24/09/2019 12:00:00 a.m.   0.0   0.0  0.0   0.0   238.0      0.0
# 3872  3873  25/09/2019 12:00:00 a.m.   0.0   0.0  0.0   0.0   237.0     -1.0
# 3873  3874  26/09/2019 12:00:00 a.m.   0.0   0.0  0.0   0.0   236.0     -1.0
# 3874  3875  27/09/2019 12:00:00 a.m.   0.0   0.0  0.0   0.0   234.0     -2.0
#
# ...

# %% [markdown]
# Chequeo que todos los datos se hayan cargado correctamente.

# %%
soja_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3875 entries, 0 to 3874
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Id          3875 non-null   int64
#  1   Fecha       3875 non-null   object
#  2   Open        3875 non-null   float64
#  3   High        3875 non-null   float64
#  4   Low         3875 non-null   float64
#  5   Last        3875 non-null   float64
#  6   Cierre      3875 non-null   float64
#  7   Aj.Dif.     3875 non-null   float64
#  8   Mon.        3875 non-null   object
#  9   OI.Vol.     3875 non-null   int64
#  10  OI.Dif.     3875 non-null   int64
#  11  Vol.Ope.    3875 non-null   int64
#  12  Unidad      3875 non-null   object
#  13  DolarB.N.   3875 non-null   object
#  14  DolarItau.  3868 non-null   object
#  15  Dif.Sem     3875 non-null   float64
# dtypes: float64(7), int64(4), object(5)
# memory usage: 484.5+ KB

# %% [markdown]
# Casteo el tipo de dato para poder trabajar mejor.

# %%
soja_df.loc[:,'Fecha'] = pd.to_datetime(soja_df['Fecha'])

# %%
soja_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3875 entries, 0 to 3874
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Id          3875 non-null   int64
#  1   Fecha       3875 non-null   datetime64[ns]
#  2   Open        3875 non-null   float64
#  3   High        3875 non-null   float64
#  4   Low         3875 non-null   float64
#  5   Last        3875 non-null   float64
#  6   Cierre      3875 non-null   float64
#  7   Aj.Dif.     3875 non-null   float64
#  8   Mon.        3875 non-null   object
#  9   OI.Vol.     3875 non-null   int64
#  10  OI.Dif.     3875 non-null   int64
#  11  Vol.Ope.    3875 non-null   int64
#  12  Unidad      3875 non-null   object
#  13  DolarB.N.   3875 non-null   object
#  14  DolarItau.  3868 non-null   object
#  15  Dif.Sem     3875 non-null   float64
# dtypes: datetime64[ns](1), float64(7), int64(4), object(4)
# memory usage: 484.5+ KB

# %%
soja_df['Año'] = soja_df['Fecha'].dt.year

# %%
soja_df.head()
# Out:
#    Id      Fecha  Open  High  Low  Last  Cierre  Aj.Dif. Mon.  OI.Vol.  \
# 0   1 2004-05-01   0.0   0.0  0.0   0.0   221.0     13.0    D        0
# 1   2 2004-06-01   0.0   0.0  0.0   0.0   221.0      0.0    D        0
# 2   3 2004-07-01   0.0   0.0  0.0   0.0   219.0     -2.0    D        0
# 3   4 2004-08-01   0.0   0.0  0.0   0.0   220.0      1.0    D        0
# 4   5 2004-09-01   0.0   0.0  0.0   0.0   220.0      0.0    D        0
#
#    OI.Dif.  Vol.Ope. Unidad DolarB.N. DolarItau.  Dif.Sem   Año
# 0        0         0   TONS      2.92      2.905   -221.0  2004
# 1        0         0   TONS      2.88       2.87   -221.0  2004
# 2        0         0   TONS     2.865      2.882   -219.0  2004
# 3        0         0   TONS     2.887      2.884   -220.0  2004
# 4        0         0   TONS     2.892        2.9   -220.0  2004

# %%
soja_boxplot = soja_df[['Año','Fecha','Cierre','Aj.Dif.']]
soja_boxplot.head()
# Out:
#     Año      Fecha  Cierre  Aj.Dif.
# 0  2004 2004-05-01   221.0     13.0
# 1  2004 2004-06-01   221.0      0.0
# 2  2004 2004-07-01   219.0     -2.0
# 3  2004 2004-08-01   220.0      1.0
# 4  2004 2004-09-01   220.0      0.0

# %% [markdown]
# Mi idea es visualizar lo que paso en el 2019

# %%
soja_boxplot = soja_boxplot.loc[soja_boxplot['Año'] == 2019]
soja_boxplot['Mes'] = soja_boxplot['Fecha'].dt.month
soja_boxplot = soja_boxplot.sort_values(by='Mes')
soja_boxplot
# Out:
#        Año      Fecha  Cierre  Aj.Dif.  Mes
# 3814  2019 2019-01-07   224.5     -2.5    1
# 3835  2019 2019-01-08   230.0     -2.0    1
# 3716  2019 2019-01-02   250.0      0.0    1
# 3715  2019 2019-01-31   250.0     -2.0    1
# 3714  2019 2019-01-30   252.0      1.0    1
# ...    ...        ...     ...      ...  ...
# 3863  2019 2019-12-09   240.0      0.0   12
# 3741  2019 2019-12-03   231.0      1.0   12
# 3763  2019 2019-12-04   214.0     -1.0   12
# 3821  2019 2019-12-07   232.0      3.0   12
# 3723  2019 2019-12-02   247.0      4.0   12
#
# [181 rows x 5 columns]

# %%
soja_boxplot['Aumento Diario'] = soja_boxplot['Aj.Dif.'] > 0
soja_boxplot
# Out:
#        Año      Fecha  Cierre  Aj.Dif.  Mes  Aumento Diario
# 3814  2019 2019-01-07   224.5     -2.5    1           False
# 3835  2019 2019-01-08   230.0     -2.0    1           False
# 3716  2019 2019-01-02   250.0      0.0    1           False
# 3715  2019 2019-01-31   250.0     -2.0    1           False
# 3714  2019 2019-01-30   252.0      1.0    1            True
# ...    ...        ...     ...      ...  ...             ...
# 3863  2019 2019-12-09   240.0      0.0   12           False
# 3741  2019 2019-12-03   231.0      1.0   12            True
# 3763  2019 2019-12-04   214.0     -1.0   12           False
# 3821  2019 2019-12-07   232.0      3.0   12            True
# 3723  2019 2019-12-02   247.0      4.0   12            True
#
# [181 rows x 6 columns]

# %% [markdown]
# Ploteo

# %%
sns.set(rc={'figure.figsize':(20,10)},font_scale=1.5)
sns.set_style('white')
ax1 = sns.boxplot(x='Mes',y='Cierre',hue= 'Aumento Diario',data=soja_boxplot, palette={'r','g'})
ax1.set_title('Cierre de la soja en 2019',fontdict={'fontsize':20})
sns.despine(offset=10, trim=True)

# %% [markdown]
# Segunda visualizacion

# %%
soja_barplot = soja_df[['Año','Cierre']]
precios_max = soja_barplot.groupby('Año')['Cierre'].agg('max')
precios_min = soja_barplot.groupby('Año')['Cierre'].agg('min')

# %%
precios_max.head()
# Out:
# Año
# 2004    252.0
# 2005    191.0
# 2006    210.0
# 2007    287.0
# 2008    369.0
# Name: Cierre, dtype: float64

# %%
dfBar = pd.DataFrame([precios_max,precios_min]).transpose()

# %%
dfBar.head()
# Out:
#       Cierre  Cierre
# Año
# 2004   252.0   151.0
# 2005   191.0   146.0
# 2006   210.0   158.0
# 2007   287.0   187.0
# 2008   369.0   192.0

# %%
dfBar.columns=['Cierre Max Año','Cierre Min Año']

# %%
dfBar.reset_index()
# Out:
#      Año  Cierre Max Año  Cierre Min Año
# 0   2004           252.0           151.0
# 1   2005           191.0           146.0
# 2   2006           210.0           158.0
# 3   2007           287.0           187.0
# 4   2008           369.0           192.0
# 5   2009           288.0           207.0
# 6   2010           369.0           213.5
# 7   2011           371.0           270.0
# 8   2012           442.0           296.0
# 9   2013           386.0           296.0
# 10  2014           380.0           261.0
# 11  2015           296.5           210.0
# 12  2016           308.5           212.5
# 13  2017           288.0           224.0
# 14  2018           326.0           235.0
# 15  2019           256.0           206.0

# %%
dfBar.plot(kind='bar',rot=45,title='Cierres máximos y mínimos anuales',color=(['b','r']))
ax=plt.gca()
ax.set_ylabel=('Precios')
ax.set_xlabel=('Años')

# %%
dfBar.hist
