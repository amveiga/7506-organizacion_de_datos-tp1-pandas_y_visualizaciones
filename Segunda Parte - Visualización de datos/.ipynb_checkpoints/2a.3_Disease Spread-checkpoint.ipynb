# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df_labels = pd.read_csv('datasets/Dengue/dengue_labels_train.csv')
df_features = pd.read_csv('datasets/Dengue/dengue_features_train.csv')

# %%
df_labels
# Out:
#      city  year  weekofyear  total_cases
# 0      sj  1990          18            4
# 1      sj  1990          19            5
# 2      sj  1990          20            4
# 3      sj  1990          21            3
# 4      sj  1990          22            6
# ...   ...   ...         ...          ...
# 1451   iq  2010          21            5
# 1452   iq  2010          22            8
# 1453   iq  2010          23            1
# 1454   iq  2010          24            1
# 1455   iq  2010          25            4
#
# [1456 rows x 4 columns]

# %%
df_features.tail()
# Out:
#      city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 1451   iq  2010          21      2010-05-28  0.342750  0.318900  0.256343
# 1452   iq  2010          22      2010-06-04  0.160157  0.160371  0.136043
# 1453   iq  2010          23      2010-06-11  0.247057  0.146057  0.250357
# 1454   iq  2010          24      2010-06-18  0.333914  0.245771  0.278886
# 1455   iq  2010          25      2010-06-25  0.298186  0.232971  0.274214
#
#        ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# 1451  0.292514                 55.30             299.334286  ...
# 1452  0.225657                 86.47             298.330000  ...
# 1453  0.233714                 58.94             296.598571  ...
# 1454  0.325486                 59.67             296.345714  ...
# 1455  0.315757                 63.22             298.097143  ...
#
#       reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
# ...

# %%
f,axs=plt.subplots(ncols=2)
g1=sns.violinplot(x='city',y='reanalysis_relative_humidity_percent',data=df_features,ax=axs[0])
g2=sns.violinplot(x='city',y='station_avg_temp_c',data=df_features,ax=axs[1])

# %%
def week_to_season(weekofyear):
    seasons = []
    for i in weekofyear:
        if i >= 48 or i < 9:
            seasons.append('SUM')
        elif 9 <= i and i < 22:
            seasons.append('AUT')
        elif 22 <= i and i < 35:
            seasons.append('WIN')
        elif 35 <= i and i < 48:
            seasons.append('SPR')
    return pd.Series(seasons)

# %%
df_labels['season'] = week_to_season(df_labels['weekofyear'])
df_labels
# Out:
#      city  year  weekofyear  total_cases season
# 0      sj  1990          18            4    AUT
# 1      sj  1990          19            5    AUT
# 2      sj  1990          20            4    AUT
# 3      sj  1990          21            3    AUT
# 4      sj  1990          22            6    WIN
# ...   ...   ...         ...          ...    ...
# 1451   iq  2010          21            5    AUT
# 1452   iq  2010          22            8    WIN
# 1453   iq  2010          23            1    WIN
# 1454   iq  2010          24            1    WIN
# 1455   iq  2010          25            4    WIN
#
# [1456 rows x 5 columns]

# %%
df_features['season'] = week_to_season(df_features['weekofyear'])
df_features['season']
# Out:
# 0       AUT
# 1       AUT
# 2       AUT
# 3       AUT
# 4       WIN
#        ...
# 1451    AUT
# 1452    WIN
# 1453    WIN
# 1454    WIN
# 1455    WIN
# Name: seasons, Length: 1456, dtype: object

# %%
sns.violinplot(x='season',y='station_avg_temp_c',hue='city',data=df_features,
              split=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-1233a65bc77c> in <module>
# ----> 1 sns.violinplot(x='season',y='station_avg_temp_c',hue='city',data=df_features,
#       2               split=True)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in violinplot(x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation, ax, **kwargs)
#    2395 ):
#    2396
# -> 2397     plotter = _ViolinPlotter(x, y, hue, data, order, hue_order,
#    2398                              bw, cut, scale, scale_hue, gridsize,
# ...

# %%
f,axs=plt.subplots(ncols=2)
g1=sns.violinplot(x='season',y='total_cases',hue='city',data=df_labels,
                split=True)
