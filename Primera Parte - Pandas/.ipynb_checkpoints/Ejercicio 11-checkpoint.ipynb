# %% [markdown]
# # Ejercicio 11
#
# Para todos los comentarios de revisión de contenido que tengan más de 20
# ocurrencias realice una matriz cuyas columnas sean esos comentarios y de índice
# los usuarios/ips con valores: True si ese usuario realizó ese comentario, sino False.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
contents = pd.read_csv('/content/drive/MyDrive/2021-2C/ORGANIZACION DE DATOS (7506)/TPs/TP1/wikipedia_dataset-2c2021/contents.csv')

# %%
contents.head()
# Out:
#                              title  ...                                    revisor_comment
# 0  Wikipedia:Artículos solicitados  ...                                     Así esta mejor
# 1                          Andorra  ...                                   Añadir contenido
# 2                        Argentina  ...  Reemplazos con [[Usuario:Benjavalero/Replacer|...
# 3             Geografía de Andorra  ...  Reemplazos con [[Usuario:Benjavalero/Replacer|...
# 4            Demografía de Andorra  ...  Correcciones ortográficas con [[Usuario:Benjav...
#
# [5 rows x 10 columns]

# %%
allRevisors = contents['revisor_ip'].fillna(contents['revisor_username'])
allRevisors
# Out:
# 0                                       Metrónomo
# 1          2800:CD0:FC1B:A900:C5A4:9E81:7175:2ED2
# 2                                       Traitrich
# 3                                           Lojwe
# 4                                          Jialxv
#                             ...
# 4132159                                  Copydays
# 4132160                                  Crls9011
# 4132161                              Gabriel Solo
# 4132162                                  Términus
# 4132163                                  Carlukas
# Name: revisor_ip, Length: 4132164, dtype: object

# %%
contents['users_or_ip'] = allRevisors
contents.head()
# Out:
#                              title  ...                             users_or_ip
# 0  Wikipedia:Artículos solicitados  ...                               Metrónomo
# 1                          Andorra  ...  2800:CD0:FC1B:A900:C5A4:9E81:7175:2ED2
# 2                        Argentina  ...                               Traitrich
# 3             Geografía de Andorra  ...                                   Lojwe
# 4            Demografía de Andorra  ...                                  Jialxv
#
# [5 rows x 11 columns]

# %%
contents_short = contents[['revisor_comment','users_or_ip']]
contents_short
# Out:
#                                            revisor_comment                             users_or_ip
# 0                                           Así esta mejor                               Metrónomo
# 1                                         Añadir contenido  2800:CD0:FC1B:A900:C5A4:9E81:7175:2ED2
# 2        Reemplazos con [[Usuario:Benjavalero/Replacer|...                               Traitrich
# 3        Reemplazos con [[Usuario:Benjavalero/Replacer|...                                   Lojwe
# 4        Correcciones ortográficas con [[Usuario:Benjav...                                  Jialxv
# ...                                                    ...                                     ...
# 4132159  termino traducción y quito plantilla en desarr...                                Copydays
# 4132160  Crls9011 trasladó la página [[Manifestación de...                                Crls9011
# 4132161  Gabriel Solo trasladó la página [[Rocasaurus]]...                            Gabriel Solo
# 4132162  Términus trasladó la página [[Medalla Conmemor...                                Términus
# 4132163  Añadiendo la [[Categoría:Localidades de Tripur...                                Carlukas
#
# [4132164 rows x 2 columns]

# %%
contents_short['ocurrences'] = contents_short.groupby(['revisor_comment']).transform('count')

# %%
contents_short=contents_short.sort_values('ocurrences',ascending=False)
contents_short
# Out:
#                                  revisor_comment   users_or_ip  ocurrences
# 2797239  Mantenimiento de Control de autoridades        Aosbot    354375.0
# 977021   Mantenimiento de Control de autoridades        Aosbot    354375.0
# 976920   Mantenimiento de Control de autoridades        Aosbot    354375.0
# 976927   Mantenimiento de Control de autoridades        Aosbot    354375.0
# 976957   Mantenimiento de Control de autoridades        Aosbot    354375.0
# ...                                          ...           ...         ...
# 4132120                                      NaN        Rodm23         NaN
# 4132127                                      NaN  Vallromana16         NaN
# 4132128                                      NaN     Lorito987         NaN
# 4132129                                      NaN     Raulito85         NaN
# 4132157                                      NaN      Carlukas         NaN
#
# [4132164 rows x 3 columns]

# %%
contents_short = contents_short[contents_short['ocurrences'] > 20]
contents_short
# Out:
#                                            revisor_comment  ... ocurrences
# 2797239            Mantenimiento de Control de autoridades  ...   354375.0
# 977021             Mantenimiento de Control de autoridades  ...   354375.0
# 976920             Mantenimiento de Control de autoridades  ...   354375.0
# 976927             Mantenimiento de Control de autoridades  ...   354375.0
# 976957             Mantenimiento de Control de autoridades  ...   354375.0
# ...                                                    ...  ...        ...
# 619256   Bot: arreglo de redirección doble a [[Museo et...  ...       21.0
# 1693940  Bot: Creando redirección a [[La gran familia.....  ...       21.0
# 2210932         Redirigiendo a «[[Hymenocallis caribaea]]»  ...       21.0
# 1982017  Añadiendo la [[Categoría:Álbumes por artista]]...  ...       21.0
# 3044723          Página redirigida a [[Frankenia hirsuta]]  ...       21.0
#
# [1440596 rows x 3 columns]

# %%
contents_short['made_comment'] = True

# %%
contents_short['revisor_comment'].value_counts()
# Out:
# Mantenimiento de Control de autoridades                                                                                                                                  354375
# Correcciones ortográficas con [[Usuario:Benjavalero/Replacer|Replacer]] (herramienta en línea de revisión de errores)                                                    128389
# Cambios menores.                                                                                                                                                          71539
# Bot: Cambiando #REDIRECT por #REDIRECCIÓN.                                                                                                                                54571
# Bot: Retirando la plantilla: R from title without diacritics                                                                                                              34762
#                                                                                                                                                                           ...
# Robot: Arreglando doble redirección → [[Calle Canal (línea de la Séptima Avenida–Broadway)]]                                                                                 21
# Eliminación de [[Categoría:Emisoras de radio fundadas en el siglo XXI]] mediante [[c:Help:Cat-a-lot|Cat-a-lot]]                                                              21
# Redirigir hacia [[Yehuda ben Moshe]] usando [[w:es:User:Axxgreazz/Monobook-Suite|monobook-suite]]                                                                            21
# Eliminando la [[Categoría:Anexos:Premios Golden Raspberry]]; Añadiendo la [[Categoría:Anexos:Premios Golden Raspberry por año‎]] mediante [[Wikipedia:HotCat|HotCat]]        21
# Reemplazos con [[Usuario:Benjavalero/Replacer|Replacer]]: «habito»                                                                                                           21
# Name: revisor_comment, Length: 6180, dtype: int64

# %%
contents_short['revisor_comment'].hasnans
# Out:
# False

# %%
pivot_contents = contents_short.pivot_table(index='users_or_ip',columns='revisor_comment',values='made_comment',fill_value=False)

# %%
pivot_contents
# Out:
# revisor_comment     #QuédateEnTuCasaYEditaWikipedia. Nuevo, localidad  ... −[[Categoría:Santos católicos]]; −[[Categoría:Santos de la Iglesia ortodoxa]]; +[[Categoría:Santo católico y ortodoxo]] mediante [[Wikipedia:HotCat|HotCat]]
# users_or_ip                                                            ...
# "BF CLUB"                                                       False  ...                                              False
# "CLUB BF"                                                       False  ...                                              False
# &beer&love                                                      False  ...                                              False
# (:Julien:)                                                      False  ...                                              False
# (KGC2) KosmoGelo II                                             False  ...                                              False
# ...                                                               ...  ...                                                ...
# 熊                                                               False  ...                                              False
# 猫に小判                                                            False  ...                                              False
# 諾恩                                                              False  ...                                              False
# 阿道                                                              False  ...                                              False
# 隼鷹                                                              False  ...                                              False
#
# [29937 rows x 6180 columns]

# %%
pivot_contents['#QuédateEnTuCasaYEditaWikipedia. Nuevo, localidad'].value_counts()
# Out:
# False    29936
# True         1
# Name: #QuédateEnTuCasaYEditaWikipedia. Nuevo, localidad, dtype: int64
